# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Solution of Task 1

# %%
# Create a NumPy array of random values
random_values = np.random.randint(0, 100, size=(4,4))

# Create a Pandas DataFrame
df = pd.DataFrame(random_values, columns=('A','B','C','D'))

# Print the DataFrame
print(df)
# Out:
#     A   B   C   D
# 0  65   9  12  68
# 1  94  15  58  54
# 2  41  97  32  81
# 3  74  82  35  45

# %% [markdown]
# Solution of Task 2

# %%
df=df.rename(columns={'A': 'Random value 1', 'B': 'Random value 2','C': 'Random value 3','D': 'Random value 4'})
df
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0              65               9              12              68
# 1              94              15              58              54
# 2              41              97              32              81
# 3              74              82              35              45

# %% [markdown]
# Solution of Task 3

# %%
df.describe()
# Out:
#        Random value 1  Random value 2  Random value 3  Random value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean        68.500000       50.750000       34.250000       62.000000
# std         21.977261       45.228125       18.839232       15.811388
# min         41.000000        9.000000       12.000000       45.000000
# 25%         59.000000       13.500000       27.000000       51.750000
# 50%         69.500000       48.500000       33.500000       61.000000
# 75%         79.000000       85.750000       40.750000       71.250000
# max         94.000000       97.000000       58.000000       81.000000

# %% [markdown]
# Solution of Task 4

# %%
df.isnull().sum()
# Out:
# Random value 1    0
# Random value 2    0
# Random value 3    0
# Random value 4    0
# dtype: int64

# %%
datatypes=df.dtypes
print(datatypes)
# Out:
# Random value 1    int64
# Random value 2    int64
# Random value 3    int64
# Random value 4    int64
# dtype: object

# %% [markdown]
# Solution of Task 5

# %%
print(df.loc[:,['Random value 2']])
print(df.loc[:,['Random value 3']])
# Out:
#    Random value 2
# 0               9
# 1              15
# 2              97
# 3              82
#    Random value 3
# 0              12
# 1              58
# 2              32
# 3              35

# %%
print(df.iloc[:,[1]])
print(df.iloc[:,[2]])
# Out:
#    Random value 2
# 0               9
# 1              15
# 2              97
# 3              82
#    Random value 3
# 0              12
# 1              58
# 2              32
# 3              35
